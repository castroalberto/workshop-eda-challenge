# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
city = pd.read_csv('./data/diamonds_city.csv')
city
# Out:
#                                               city_id           city
# 0   0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...      Amsterdam
# 1   1e73b1647343b286269d517e6f07e6e07ccef10cd7b785...         Zurich
# 2   2bd25cd960aba8b706e2b67f2bb38b750ee5384b0e9883...      Las Vegas
# 3   5a59ef2e40c5f89adb8c0c6ad0a8019b0e252fff530cf2...  New York City
# 4   5dd272b4f316b776a7b8e3d0894b37e1e42be3d5d3b204...          Paris
# 5   68371d5bdaab31b5cbc25fbf94b8f9c1238294fc50e715...       Tel Aviv
# 6   6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...          Dubai
# 7   89c7286890f7347ab235234e74d406596a127ae3679042...       Kimberly
# 8   ba04d229e496b8383a4df91f5e77c194a95cf1a069b0b2...          Surat
# 9   ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...        Antwerp
# 10  e9c722cbefc2f055ae60b4e2cbe73a2d99537eab0c37f3...         Madrid
# 11  ecc0e7dc084f141b29479058967d0bc07dee25d9690a98...         London
# 12  ed76f191621cf6ed77eab6a8013d1cb4bdfa89a75a24aa...     Luxembourg

# %%
transactional = pd.read_csv('./data/diamonds_transactional.csv')
transactional
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
# ...                                                  ...    ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...  10070
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...  12615
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   5457
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...    456
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   6232
#
#                                                  city_id  carat
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...   0.32
# ...

# %%
clarity = pd.read_csv('./data/diamonds_clarity.csv')
clarity
# Out:
#                                           clarity_id clarity
# 0  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 1  3f9db06236e9719b61c826b612b882fa702ec81574e44c...    VVS2
# 2  66686ae1f0c9c400ba32dc600a34ff0aa173395bcbc2d8...    VVS1
# 3  7020fd7aaf1656dea5c0c0c3d4bb5a28ebf6243fba95d3...      IF
# 4  bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1
# 5  c2818bc4e5ec4ae4a357a0df6fed73652e169ec676f7d4...      I1
# 6  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 7  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2

# %%
color = pd.read_csv('./data/diamonds_color.csv')
color
# Out:
#                                             color_id color
# 0  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1  3f39d5c348e5b79d06e842c114e6cc571583bbf44e4b0e...     D
# 2  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H
# 3  6da43b944e494e885e69af021f93c6d9331c78aa228084...     J
# 4  a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...     I
# 5  a9f51566bd6705f7ea6ad54bb9deb449f795582d6529a0...     E
# 6  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F

# %%
cut = pd.read_csv('./data/diamonds_cut.csv')
cut
# Out:
#                                               cut_id        cut
# 0  388655e25e91872329272fc10128ef5354b3b19a05d7e8...  Very Good
# 1  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...      Ideal
# 2  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...       Good
# 3  de88c121a82a06352bf1aaceba20578356408a334ba046...    Premium
# 4  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...       Fair

# %%
dimensions = pd.read_csv('./data/diamonds_dimensions.csv')
dimensions
# Out:
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z
# 0      6.79  4.25
# ...

# %%
properties = pd.read_csv('./data/diamonds_properties.csv')
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index_id    40455 non-null  object
#  1   cut_id      40455 non-null  object
#  2   color_id    40455 non-null  object
#  3   clarity_id  40455 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
df = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(properties, cut, on='cut_id', how='left'),      
                              color, on='color_id', how='left'), 
                     clarity, on='clarity_id', how='left'),
                     dimensions, on='index_id', how='left'),
                     transactional, on='index_id', how='left'),
                     city, on='city_id', how= 'left')



df.head(2)
# Out:
#                                             index_id  \
# 0  5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1  6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
#
#                                               cut_id  \
# 0  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1  388655e25e91872329272fc10128ef5354b3b19a05d7e8...
#
#                                             color_id  \
# 0  6da43b944e494e885e69af021f93c6d9331c78aa228084...
# 1  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...
#
#                                           clarity_id        cut color clarity  \
# 0  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...    Premium     J     VS2
# 1  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...  Very Good     H     VS2
#
#    depth  table     x     y     z  price  \
# 0   62.4   58.0  6.83  6.79  4.25   4268
# 1   63.0   57.0  4.35  4.38  2.75    505
#
#                                              city_id  carat      city
# ...

# %%
df = df.drop(['cut_id', 'color_id', 'clarity_id','city_id'], axis=1)
df
# Out:
#                                                 index_id        cut color  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...    Premium     J
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...  Very Good     H
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...       Fair     G
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...       Good     D
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...      Ideal     G
# ...                                                  ...        ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...      Ideal     G
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...       Good     F
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...      Ideal     H
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...      Ideal     J
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...      Ideal     I
#
#       clarity  depth  table     x     y     z  price  carat           city
# ...

# %%
# freq 'cut'
cut_counts = df['cut'].value_counts()

# %%
# proporcional a los datos
cut_proportions = cut_counts / len(df)

print(cut_proportions)
# Out:
# cut
# Ideal        0.400939
# Premium      0.253615
# Very Good    0.224818
# Good         0.090545
# Fair         0.030083
# Name: count, dtype: float64

# %%
# Visualizar la distribución de precios
plt.figure
sns.histplot(df['price'], bins=20, color='green')
plt.title('Distribución de precios ($)')
plt.xlabel('Precio ($)')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Visualizar la relación entre carat y precio
plt.figure

sns.scatterplot(x='carat', y='price', data=df, color='orange')
plt.title('Relación entre quilates / precio')
plt.xlabel('Carat')
plt.ylabel('Precio')
plt.show()

# %%
# antidad de diamantes en cada categoría de corte
plt.figure
sns.countplot(x='cut', data=df, palette='pastel')

plt.title('Cantidad de Diamantes por Categoría de Corte')
plt.xlabel('Categoría de Corte')
plt.ylabel('Cantidad')
plt.show()
# Out:
# /var/folders/ds/9vmwhs_s1b719j30p7xc47gh0000gn/T/ipykernel_11594/928351543.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cut', data=df, palette='pastel')

# %%
plt.figure
sns.boxplot(x='cut', y='price', data=df, palette='pastel')
plt.title('Comparación de Cortes y Precios de Diamantes')
plt.xlabel('Corte')
plt.ylabel('Precio')
plt.show()
# Out:
# /var/folders/ds/9vmwhs_s1b719j30p7xc47gh0000gn/T/ipykernel_11594/631712766.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cut', y='price', data=df, palette='pastel')

# %%
# Set the price threshold
price_threshold = 1

# Filter the DataFrame to include only rows where price is above the threshold
filtered_df = df[df['price'] > price_threshold]

# %%
# Create the boxplot with the filtered DataFrame
plt.figure()
sns.boxplot(x='cut', y='price', data=filtered_df, palette='pastel')
plt.title('Comparación de Cortes y Precios de Diamantes (Precio > 10000)')
plt.xlabel('Corte')
plt.ylabel('Precio')
plt.show()
# Out:
# /var/folders/ds/9vmwhs_s1b719j30p7xc47gh0000gn/T/ipykernel_11594/3199632510.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cut', y='price', data=filtered_df, palette='pastel')

# %%
pd.plotting.scatter_matrix(df[['carat', 'depth', 'table', 'city', 'price']], figsize=(12, 10), diagonal='hist')
plt.suptitle('Scatterplot Matrix de Variables Numéricas', y=1.02)
plt.show()
